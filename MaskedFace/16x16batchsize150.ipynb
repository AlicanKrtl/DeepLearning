# %%
import plaidml.keras
plaidml.keras.install_backend()

import os
os.environ["KERAS_BACKEND"] = "plaidml.keras.backend"
cwd = os.getcwd()

from keras import backend as K

# %%
import numpy as np
import pandas as pd
from keras.preprocessing.image import ImageDataGenerator, load_img
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import random
from keras.models import Sequential
from keras.layers import Cropping2D

# %%
import glob
import cv2 as cv

path = glob.glob("C:\\Users\\alikr\\Projects\\JupyterNotebook\\Deep Learning\\Çalışmalar\\maskedAndUnmasked\\veriler\\*\\*")

# %%
categories = []
imgnames = []
for i in range(len(path)):
    imgnames.append(path[i].split("\\")[-1])
    a = ((path[i].split("\\")[-1]).rstrip(".jpg")).split("_")[1:]
    if len(a)==1:
        categories.append("Correct")
    else:
        categories.append("False")

# %%
df = pd.DataFrame({
'filename': path,
'category': categories,
'imgname': imgnames
})
df_ = df.sample(frac=1).reset_index(drop=True)
df_
# Out:
#                                                  filename category  \
# 0       C:\Users\alikr\Projects\JupyterNotebook\Deep L...    False
# 1       C:\Users\alikr\Projects\JupyterNotebook\Deep L...  Correct
# 2       C:\Users\alikr\Projects\JupyterNotebook\Deep L...    False
# 3       C:\Users\alikr\Projects\JupyterNotebook\Deep L...    False
# 4       C:\Users\alikr\Projects\JupyterNotebook\Deep L...  Correct
# ...                                                   ...      ...
# 133777  C:\Users\alikr\Projects\JupyterNotebook\Deep L...  Correct
# 133778  C:\Users\alikr\Projects\JupyterNotebook\Deep L...    False
# 133779  C:\Users\alikr\Projects\JupyterNotebook\Deep L...  Correct
# 133780  C:\Users\alikr\Projects\JupyterNotebook\Deep L...    False
# 133781  C:\Users\alikr\Projects\JupyterNotebook\Deep L...  Correct
#
#                           imgname
# 0       12959_Mask_Mouth_Chin.jpg
# 1                  63893_Mask.jpg
# 2       39398_Mask_Mouth_Chin.jpg
# 3       23682_Mask_Mouth_Chin.jpg
# 4                  33048_Mask.jpg
# ...                           ...
# 133777             18257_Mask.jpg
# 133778  30619_Mask_Mouth_Chin.jpg
# 133779             16164_Mask.jpg
# 133780  19588_Mask_Mouth_Chin.jpg
# 133781             55318_Mask.jpg
#
# [133782 rows x 3 columns]

# %%
sample = random.choice(path)
image = load_img(sample)
plt.imshow(image)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization

model = Sequential()

model.add(Conv2D(16, (3, 3), activation='relu', input_shape=(16, 16, 3)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size= (3, 3)))
model.add(Dropout(0.4))

model.add(Flatten())
model.add(Dense(32, activation = 'relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(2, activation = 'softmax')) 

model.compile(loss = 'categorical_crossentropy', optimizer = 'rmsprop', metrics = ['accuracy'])

model.summary()
# Out:
# INFO:plaidml:Opening device "opencl_amd_gfx1012.0"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 14, 14, 16)        448
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 14, 14, 16)        64
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 4, 4, 16)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4, 4, 16)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                8224
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32)                128
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 66
# =================================================================
# Total params: 8,930
# Trainable params: 8,834
# Non-trainable params: 96
# _________________________________________________________________

# %%
from keras.callbacks import EarlyStopping, ReduceLROnPlateau

earlystop = EarlyStopping(patience = 3)

learning_rate_reduction = ReduceLROnPlateau(monitor = "val_acc",
                                           patience = 2,
                                           verbose = 1,
                                           factor = 0.5,
                                           min_lr = 0.0001)

# %%
callbacks = [earlystop, learning_rate_reduction]

# %%
train_df, validate_df = train_test_split(df_, test_size = 0.05, random_state = 42)

# %%
train_df = train_df.reset_index(drop=True)
validate_df = validate_df.reset_index(drop = True)

# %%
train_df["category"].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
validate_df["category"].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
total_train = train_df.shape[0]
total_validate = validate_df.shape[0]
batch_size = 150

# %%
train_datagen = ImageDataGenerator(
    rescale = 1./255,
    shear_range = 0.1,
    zoom_range = 0.2,
    horizontal_flip = True
)

# %%
train_generator = train_datagen.flow_from_dataframe(
    train_df,
    x_col = 'filename',
    y_col = 'category',
    class_mode = "categorical",
    target_size = (16, 16),
    batch_size = batch_size
)
# Out:
# Found 127092 validated image filenames belonging to 2 classes.

# %%
validation_datagen = ImageDataGenerator(rescale = 1./255)
validation_generator = validation_datagen.flow_from_dataframe(
    validate_df,
    x_col = "filename",
    y_col = "category",
    target_size = (16, 16),
    class_mode = "categorical",
    batch_size = batch_size
)
# Out:
# Found 6690 validated image filenames belonging to 2 classes.

# %%
example_df = train_df.sample(n=1).reset_index(drop=True)
example_generator = train_datagen.flow_from_dataframe(
    example_df,
    x_col = "filename",
    y_col = "category",
    target_size = (16, 16),
    class_mode = "categorical"
)
# Out:
# Found 1 validated image filenames belonging to 1 classes.

# %%
plt.figure(figsize = (12, 12))
for i in range(0, 15):
    plt.subplot(5, 3, i+1)
    for X_batch, Y_batch in example_generator:
        image = X_batch[0]
        plt.imshow(image)
        break
plt.tight_layout()
plt.show()

# %%
epochs = 10
history = model.fit_generator(
    train_generator,
    epochs = epochs,
    validation_data = validation_generator,
    validation_steps = total_validate//batch_size,
    steps_per_epoch = total_train//batch_size,
    callbacks = callbacks
)
# Out:
# Epoch 1/10
# 847/847 [==============================] - 2385s 3s/step - loss: 0.5037 - acc: 0.7713 - val_loss: 0.6610 - val_acc: 0.6897
# Epoch 2/10
# 847/847 [==============================] - 2368s 3s/step - loss: 0.4230 - acc: 0.8140 - val_loss: 0.3901 - val_acc: 0.8255
# Epoch 3/10
# 847/847 [==============================] - 2360s 3s/step - loss: 0.4060 - acc: 0.8241 - val_loss: 0.3764 - val_acc: 0.8338
# Epoch 4/10
# 847/847 [==============================] - 2547s 3s/step - loss: 0.4034 - acc: 0.8273 - val_loss: 0.3664 - val_acc: 0.8398
# Epoch 5/10
# 847/847 [==============================] - 2846s 3s/step - loss: 0.4009 - acc: 0.8276 - val_loss: 0.3603 - val_acc: 0.8431
# Epoch 6/10
# 847/847 [==============================] - 2987s 4s/step - loss: 0.3999 - acc: 0.8277 - val_loss: 0.3719 - val_acc: 0.8359
# Epoch 7/10
# 492/847 [================>.............] - ETA: 18:38 - loss: 0.3946 - acc: 0.8303
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-2d7b6a22b431> in <module>
#       1 epochs = 10
# ----> 2 history = model.fit_generator(
#       3     train_generator,
#       4     epochs = epochs,
#       5     validation_data = validation_generator,
#
# ~\anaconda3\lib\site-packages\keras\legacy\interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ~\anaconda3\lib\site-packages\keras\engine\training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1403         ```
#    1404         """
# -> 1405         return training_generator.fit_generator(
#    1406             self, generator,
#    1407             steps_per_epoch=steps_per_epoch,
#
# ~\anaconda3\lib\site-packages\keras\engine\training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     179             batch_index = 0
#     180             while steps_done < steps_per_epoch:
# --> 181                 generator_output = next(output_generator)
#     182
#     183                 if not hasattr(generator_output, '__len__'):
#
# ~\anaconda3\lib\site-packages\keras\utils\data_utils.py in get(self)
#     593         try:
#     594             while self.is_running():
# --> 595                 inputs = self.queue.get(block=True).get()
#     596                 self.queue.task_done()
#     597                 if inputs is not None:
#
# ~\anaconda3\lib\multiprocessing\pool.py in get(self, timeout)
#     763
#     764     def get(self, timeout=None):
# --> 765         self.wait(timeout)
#     766         if not self.ready():
#     767             raise TimeoutError
#
# ~\anaconda3\lib\multiprocessing\pool.py in wait(self, timeout)
#     760
#     761     def wait(self, timeout=None):
# --> 762         self._event.wait(timeout)
#     763
#     764     def get(self, timeout=None):
#
# ~\anaconda3\lib\threading.py in wait(self, timeout)
#     556             signaled = self._flag
#     557             if not signaled:
# --> 558                 signaled = self._cond.wait(timeout)
#     559             return signaled
#     560
#
# ~\anaconda3\lib\threading.py in wait(self, timeout)
#     300         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     301             if timeout is None:
# --> 302                 waiter.acquire()
#     303                 gotit = True
#     304             else:
#
# KeyboardInterrupt:

# %%
loss, accuracy = model.evaluate_generator(validation_generator, total_validate//batch_size, workers = 12)
print("Test: accuracy = %f ; loss = %f" % (accuracy, loss))
# Out:
# Test: accuracy = 0.843939 ; loss = 0.357318

# %%
def plot_model_history(model_history, acc ='acc', val_acc = 'val_acc'):
    fig, axs = plt.subplots(1, 2, figsize= (15,5))
    axs[0].plot(range(1, len(model_history.history[acc])+1), model_history.history[acc])
    axs[0].plot(range(1, len(model_history.history[val_acc])+1), model_history.history[val_acc])
    axs[0].set_title("Model Accuracy")
    axs[0].set_ylabel("Accuracy")
    axs[0].set_xlabel("Epoch")
    axs[0].set_xticks(np.arange(1, len(model_history.history[acc])+1), len(model_history.history[acc])/10)
    axs[0].legend(["train", "val"], loc = "best")
    axs[1].plot(range(1, len(model_history.history["loss"])+1), model_history.history["loss"])
    axs[1].plot(range(1, len(model_history.history["val_loss"])+1), model_history.history["val_loss"])
    axs[1].set_title("Model Loss")
    axs[1].set_ylabel("Loss")
    axs[1].set_xlabel("Epoch")
    axs[1].set_xticks(np.arange(1, len(model_history.history["loss"])+1), len(model_history.history["loss"])/10)
    axs[1].legend(["train", "val"], loc = "best")
    plt.show()

plot_model_history(history)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-4ff572e718a8> in <module>
#      17     plt.show()
#      18
# ---> 19 plot_model_history(history)
#
# NameError: name 'history' is not defined
